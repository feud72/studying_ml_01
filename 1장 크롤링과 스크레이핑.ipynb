# %% [markdown]
# ## 데이터 다운로드하기

# %%
import urllib.request

url = "http://uta.pw/shodou/img/28/214.png"
savename = "test.png"

urllib.request.urlretrieve(url, savename)

print("저장되었습니다.")
# Out:
# 저장되었습니다.

# %% [markdown]
# urllib.request.urlretrieve(url, filename=None, reporthook=None, data=None): [Link](https://docs.python.org/ko/3/library/urllib.request.html?highlight=urlretrieve#urllib.request.urlretrieve)
# - Copy a network object denoted by a URL to a local file. If the URL points to a local file, the object will not be copied unless filename is supplied. Return a tuple (filename, headers) where filename is the local file name under which the object can be found, and headers is whatever the info() method of the object returned by urlopen() returned (for a remote object). Exceptions are the same as for urlopen().
#
# - The second argument, if present, specifies the file location to copy to (if absent, the location will be a tempfile with a generated name). The third argument, if present, is a callable that will be called once on establishment of the network connection and once after each block read thereafter. The callable will be passed three arguments; a count of blocks transferred so far, a block size in bytes, and the total size of the file. The third argument may be -1 on older FTP servers which do not return a file size in response to a retrieval request.

# %%
import urllib.request

url = "http://api.aoikujira.com/ip/ini"
res = urllib.request.urlopen(url)
data = res.read()

data
# Out:
# b'[ip]\nAPI_URI=http://api.aoikujira.com/ip/get.php\nREMOTE_ADDR=223.38.62.202\nREMOTE_HOST=223.38.62.202\nREMOTE_PORT=60150\nHTTP_HOST=api.aoikujira.com\nHTTP_USER_AGENT=Python-urllib/3.8\nHTTP_ACCEPT_LANGUAGE=\nHTTP_ACCEPT_CHARSET=\nSERVER_PORT=80\nFORMAT=ini\n\n'

# %%
text = data.decode('utf-8')
print(text)
# Out:
# [ip]
# API_URI=http://api.aoikujira.com/ip/get.php
# REMOTE_ADDR=223.38.62.202
# REMOTE_HOST=223.38.62.202
# REMOTE_PORT=60150
# HTTP_HOST=api.aoikujira.com
# HTTP_USER_AGENT=Python-urllib/3.8
# HTTP_ACCEPT_LANGUAGE=
# HTTP_ACCEPT_CHARSET=
# SERVER_PORT=80
# FORMAT=ini

# %%
import urllib.request
import urllib.parse
API = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
values = {
    'stnId': '108'
}
params = urllib.parse.urlencode(values)
url = API + "?" + params
print("url=", url)
data = urllib.request.urlopen(url).read()
text = data.decode("utf-8")
print(text)
# Out:
# url= http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2020년 01월 14일 (화)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2020년 01월 14일 (화)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# 	<header>
# 		<title>전국 육상중기예보</title>
# 		<tm>202001140600</tm>
# 		<wf><![CDATA[기압골의 영향으로 19일은 서울.경기도와 강원영서, 충청도, 전북, 제주도에 비 또는 눈이 오겠고, 22~24일은 제주도에 비가 오겠습니다.<br />그 밖의 날은 고기압의 가장자리에 들어 가끔 구름많겠습니다. <br />기온은 평년(최저기온: -12~0℃, 최고기온: 1~8℃)보다 조금 높겠습니다.<br />강수량은 평년(0~3mm)보다 적겠으나, 서울.경기도와 강원영서, 충청도, 전북은 비슷하겠고, 제주도는 조금 많겠습니다.]]></wf>
# 	</header>
# 	<body>
#
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>서울</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 눈</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>인천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 눈</wf>
# 					<tmn>0</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>수원</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 눈</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>파주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-9</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-9</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-8</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 눈</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-7</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-7</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-7</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-9</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>이천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-8</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-8</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 눈</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-7</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>평택</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 눈</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>강원도영서</province>
# 				<city>춘천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-7</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-7</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 눈</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>강원도영서</province>
# 				<city>원주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 눈</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>강원도영동</province>
# 				<city>강릉</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>대전ㆍ세종ㆍ충청남도</province>
# 				<city>대전</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-5</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 비/눈</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대전ㆍ세종ㆍ충청남도</province>
# 				<city>세종</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 비/눈</wf>
# 					<tmn>-5</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대전ㆍ세종ㆍ충청남도</province>
# 				<city>홍성</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 비/눈</wf>
# 					<tmn>-3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>충청북도</province>
# 				<city>청주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 비/눈</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>충청북도</province>
# 				<city>충주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-7</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-7</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 비/눈</wf>
# 					<tmn>-5</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-5</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-6</tmn>
# 					<tmx>2</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>충청북도</province>
# 				<city>영동</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-6</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-7</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-6</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 비/눈</wf>
# 					<tmn>-6</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-4</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-6</tmn>
# 					<tmx>3</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>광주ㆍ전라남도</province>
# 				<city>광주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>광주ㆍ전라남도</province>
# 				<city>목포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>2</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>2</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>2</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>광주ㆍ전라남도</province>
# 				<city>여수</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>2</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>2</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>2</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>2</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>2</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>2</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>3</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>4</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# ...
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-6</tmn>
# 					<tmx>4</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대구ㆍ경상북도</province>
# 				<city>포항</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대구ㆍ경상북도</province>
# 				<city>경주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-3</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>-2</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-3</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대구ㆍ경상북도</province>
# 				<city>울진</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-1</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>0</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>-2</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대구ㆍ경상북도</province>
# 				<city>울릉도</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>0</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>3</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>3</tmn>
# 					<tmx>7</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>3</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>3</tmn>
# 					<tmx>6</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>2</tmn>
# 					<tmx>5</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>제주도</province>
# 				<city>제주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>5</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>5</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>5</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>5</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>5</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>5</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>7</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>7</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>6</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>6</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>7</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>6</tmn>
# 					<tmx>9</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>5</tmn>
# 					<tmx>8</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>제주도</province>
# 				<city>서귀포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>5</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-17 12:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>5</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 00:00</tmEf>
# 					<wf>맑음</wf>
# 					<tmn>4</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>10</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-18 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>4</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>20</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>5</tmn>
# 					<tmx>11</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-19 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>5</tmn>
# 					<tmx>11</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>6</tmn>
# 					<tmx>12</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-20 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>6</tmn>
# 					<tmx>12</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>7</tmn>
# 					<tmx>12</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2020-01-21 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>7</tmn>
# 					<tmx>12</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-22 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>8</tmn>
# 					<tmx>12</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-23 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>8</tmn>
# 					<tmx>11</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2020-01-24 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>5</tmn>
# 					<tmx>10</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
#
# 	</body>
# </description>
# </item>
# </channel>
# </rss>

# %% [markdown]
# ## 스크레이핑하기

# %%
from bs4 import BeautifulSoup

html = """
<html><body>
<h1 id="title">웹 스크레이핑이란?</h1>
<p id="body">웹 페이지를 분석하는 것</p>
<p>원하는 부분을 추출하는 것</p>
</body>
</html>
"""

soup = BeautifulSoup(html, 'html.parser')

# h1 = soup.html.body.h1
# p1 = soup.html.body.p
# p2 = p1.next_sibling.next_sibling

h1 = soup.find(id="title")
body = soup.find(id="body")

print(f"#title = {h1.string}")
print(f"#body = {body.string}")
# print(f"p2 = {p2.string}")
# Out:
# #title = 웹 스크레이핑이란?
# #body = 웹 페이지를 분석하는 것

# %%
from bs4 import BeautifulSoup

html = """
<html><body>
<ul>
<li><a href="http://www.naver.com">naver</a></li>
<li><a href="http://www.daum.net">daum</a></li>
</ul>
</body>
</html>
"""

soup = BeautifulSoup(html, 'html.parser')

links = soup.find_all("a")

for a in links:
    href = a.attrs['href']
    text = a.string
    print(text, ">", href)
# Out:
# naver > http://www.naver.com
# daum > http://www.daum.net

# %%
from bs4 import BeautifulSoup
import urllib.request as req

url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"

res = req.urlopen(url)

soup = BeautifulSoup(res, "html.parser")

title = soup.find("title").string
wf = soup.find("wf").string
print(title)
print(wf)
# Out:
# 기상청 육상 중기예보
# 기압골의 영향으로 19일은 서울.경기도와 강원영서, 충청도, 전북, 제주도에 비 또는 눈이 오겠고, 22~24일은 제주도에 비가 오겠습니다.<br />그 밖의 날은 고기압의 가장자리에 들어 가끔 구름많겠습니다. <br />기온은 평년(최저기온: -12~0℃, 최고기온: 1~8℃)보다 조금 높겠습니다.<br />강수량은 평년(0~3mm)보다 적겠으나, 서울.경기도와 강원영서, 충청도, 전북은 비슷하겠고, 제주도는 조금 많겠습니다.

# %%
# from bs4 import BeautifulSoup
# import urllib.request as req

# url = "http://info.finance.naver.com/marketindex/"
# res = req.urlopen(url)

# soup = BeautifulSoup(res, "html.parser")

# price = soup.select_one("div.head_info > span.value").string

# print("usd/krw =", price)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-938ce26ead41> in <module>
#       3
#       4 url = "http://info.finance.naver.com/marketindex/"
# ----> 5 res = req.urlopen(url)
#       6
#       7 soup = BeautifulSoup(res, "html.parser")
#
# /data/data/com.termux/files/usr/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /data/data/com.termux/files/usr/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /data/data/com.termux/files/usr/lib/python3.8/urllib/request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# /data/data/com.termux/files/usr/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# /data/data/com.termux/files/usr/lib/python3.8/urllib/request.py in http_open(self, req)
#    1346
#    1347     def http_open(self, req):
# -> 1348         return self.do_open(http.client.HTTPConnection, req)
#    1349
#    1350     http_request = AbstractHTTPHandler.do_request_
#
# /data/data/com.termux/files/usr/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317         try:
#    1318             try:
# -> 1319                 h.request(req.get_method(), req.selector, req.data, headers,
#    1320                           encode_chunked=req.has_header('Transfer-encoding'))
#    1321             except OSError as err: # timeout error
#
# /data/data/com.termux/files/usr/lib/python3.8/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228                 encode_chunked=False):
#    1229         """Send a complete request to the server."""
# -> 1230         self._send_request(method, url, body, headers, encode_chunked)
#    1231
#    1232     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /data/data/com.termux/files/usr/lib/python3.8/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             # default charset of iso-8859-1.
#    1275             body = _encode(body, 'body')
# -> 1276         self.endheaders(body, encode_chunked=encode_chunked)
#    1277
#    1278     def getresponse(self):
#
# /data/data/com.termux/files/usr/lib/python3.8/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223         else:
#    1224             raise CannotSendHeader()
# -> 1225         self._send_output(message_body, encode_chunked=encode_chunked)
#    1226
#    1227     def request(self, method, url, body=None, headers={}, *,
#
# /data/data/com.termux/files/usr/lib/python3.8/http/client.py in _send_output(self, message_body, encode_chunked)
#    1002         msg = b"\r\n".join(self._buffer)
#    1003         del self._buffer[:]
# -> 1004         self.send(msg)
#    1005
#    1006         if message_body is not None:
#
# /data/data/com.termux/files/usr/lib/python3.8/http/client.py in send(self, data)
#     942         if self.sock is None:
#     943             if self.auto_open:
# --> 944                 self.connect()
#     945             else:
#     946                 raise NotConnected()
#
# /data/data/com.termux/files/usr/lib/python3.8/http/client.py in connect(self)
#     913     def connect(self):
#     914         """Connect to the host and port specified in __init__."""
# --> 915         self.sock = self._create_connection(
#     916             (self.host,self.port), self.timeout, self.source_address)
#     917         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /data/data/com.termux/files/usr/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     794             if source_address:
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#     798             err = None
#
# KeyboardInterrupt:

# %% [markdown]
# ## CSS 선택자

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import urllib.parse

url = "https://ko.m.wikisource.org/wiki/"
author = "저자:윤동주"
url = url + urllib.parse.quote(author)
res = req.urlopen(url)
soup = BeautifulSoup(res, "html.parser")

# "html.client-js.mf-font-size-null.issues-group-B body.mediawiki.ltr.sitedir-ltr.mw-hide-empty-elt.ns-100.ns-subject.mw-editable.page-저자_윤동주.rootpage-저자_윤동주.stable.skin-minerva.action-view.animations div#mw-mf-viewport div#mw-mf-page-center main#content.mw-body div#bodyContent.content div#mw-content-text.mw-content-ltr div.mw-parser-output section#content-collapsible-block-0.mf-section-1.collapsible-block.open-block ul li ul li a"

a_list = soup.select("section.mf-section-1 > ul > li a")

# soup

for a in a_list:
    name = a.string
    print("-", name)
# Out:
# - 하늘과 바람과 별과 시
# - 증보판
# - 서시
# - 자화상
# - 소년
# - 눈 오는 지도
# - 돌아와 보는 밤
# - 병원
# - 새로운 길
# - 간판 없는 거리
# - 태초의 아침
# - 또 태초의 아침
# - 새벽이 올 때까지
# - 무서운 시간
# - 십자가
# - 바람이 불어
# - 슬픈 족속
# - 눈감고 간다
# - 또 다른 고향
# - 길
# - 별 헤는 밤
# - 흰 그림자
# - 사랑스런 추억
# - 흐르는 거리
# - 쉽게 씌어진 시
# - 봄
# - 참회록
# - 간(肝)
# - 위로
# - 팔복
# - 못자는밤
# - 달같이
# - 고추밭
# - 아우의 인상화
# - 사랑의 전당
# - 이적
# - 비오는 밤
# - 산골물
# - 유언
# - 창
# - 바다
# - 비로봉
# - 산협의 오후
# - 명상
# - 소낙비
# - 한난계
# - 풍경
# - 달밤
# - 장
# - 밤
# - 황혼이 바다가 되어
# - 아침
# - 빨래
# - 꿈은 깨어지고
# - 산림
# - 이런날
# - 산상
# - 양지쪽
# - 닭
# - 가슴 1
# - 가슴 2
# - 비둘기
# - 황혼
# - 남쪽 하늘
# - 창공
# - 거리에서
# - 삶과 죽음
# - 초한대
# - 산울림
# - 해바라기 얼굴
# - 귀뚜라미와 나와
# - 애기의 새벽
# - 햇빛·바람
# - 반디불
# - 둘 다
# - 거짓부리
# - 눈
# - 참새
# - 버선본
# - 편지
# - 봄
# - 무얼 먹구 사나
# - 굴뚝
# - 햇비
# - 빗자루
# - 기왓장 내외
# - 오줌싸개 지도
# - 병아리
# - 조개껍질
# - 겨울
# - 트루게네프의 언덕
# - 달을 쏘다
# - 별똥 떨어진 데
# - 화원에 꽃이 핀다
# - 종시

# %% [markdown]
# ## 링크에 있는 것을 한꺼번에 내려받기

# %%
from urllib.parse import urljoin

base = "http://example.com/html/a.html"

print(urljoin(base, "b.html"))
print(urljoin(base, "sub/c.html"))
print(urljoin(base, "../index.html"))
print(urljoin(base, "../img/hoge.png"))
print(urljoin(base, "../css/hoge.css"))
# Out:
# http://example.com/html/b.html
# http://example.com/html/sub/c.html
# http://example.com/index.html
# http://example.com/img/hoge.png
# http://example.com/css/hoge.css

# %% [markdown]
# urllib.parse.urljoin(base, url, allow_fragments=True): [Link](https://docs.python.org/ko/3/library/urllib.parse.html#urllib.parse.urljoin)
# - Construct a full (《absolute》) URL by combining a 《base URL》 (base) with another URL (url). Informally, this uses components of the base URL, in particular the addressing scheme, the network location and (part of) the path, to provide missing components in the relative URL.

# %%
from bs4 import BeautifulSoup
from urllib.request import *
from urllib.parse import *
from os import makedirs
import os.path, time, re

proc_files = {}

def enum_links(html, base):
    soup = BeautifulSoup(html, "html.parser")
    links = soup.select("link[rel='stylesheet']")
    links += soup.select("a[href]")
    result = []
    for a in links:
        href = a.attrs['href']
        url = urljoin(base, href)
        result.append(url)
    return result

def download_file(url):
    o = urlparse(url)
    savepath = "./" + o.netloc + o.path
    if re.search(r"/$", savepath):
        savepath += "index.html"
    savedir = os.path.dirname(savepath)
    if os.path.exists(savepath):
        return savepath
    if not os.path.exists(savedir):
        print("mkdir=", savedir)
        makedirs(savedir)
    try:
        print("download=", url)
        urlretrieve(url, savepath)
        time.sleep(1)
        return savepath
    except:
        print("다운 실패", url)
        return None
    
def analyze_html(url, root_url):
    savepath = download_file(url)
    if savepath is None:
        return
    if savepath in proc_files:
        return
    proc_files[savepath] = True
    print("analyze_html=", url)
    html = open(savepath, "r", encoding="utf-8").read()
    links = enum_links(html, url)
    for link_url in links:
        if link_url.find(root_url) != 0:
            if not re.search(r".css$", link_url):
                continue
        if re.search(r".(html|htm)$", link_url):
            analyze_html(link_url, root_url)
            continue
        download_file(link_url)
        
url = "https://docs.python.org/3.8/library/"
analyze_html(url, url)
# Out:
# analyze_html= https://docs.python.org/3.8/library/
# analyze_html= https://docs.python.org/3.8/library/intro.html
# analyze_html= https://docs.python.org/3.8/library/functions.html
# analyze_html= https://docs.python.org/3.8/library/constants.html
# analyze_html= https://docs.python.org/3.8/library/stdtypes.html
# analyze_html= https://docs.python.org/3.8/library/exceptions.html
# analyze_html= https://docs.python.org/3.8/library/text.html
# analyze_html= https://docs.python.org/3.8/library/string.html
# analyze_html= https://docs.python.org/3.8/library/re.html
# analyze_html= https://docs.python.org/3.8/library/difflib.html
# analyze_html= https://docs.python.org/3.8/library/textwrap.html
# analyze_html= https://docs.python.org/3.8/library/unicodedata.html
# analyze_html= https://docs.python.org/3.8/library/stringprep.html
# analyze_html= https://docs.python.org/3.8/library/readline.html
# analyze_html= https://docs.python.org/3.8/library/rlcompleter.html
# analyze_html= https://docs.python.org/3.8/library/binary.html
# analyze_html= https://docs.python.org/3.8/library/struct.html
# analyze_html= https://docs.python.org/3.8/library/codecs.html
# analyze_html= https://docs.python.org/3.8/library/datatypes.html
# analyze_html= https://docs.python.org/3.8/library/datetime.html
# analyze_html= https://docs.python.org/3.8/library/calendar.html
# analyze_html= https://docs.python.org/3.8/library/collections.html
# analyze_html= https://docs.python.org/3.8/library/collections.abc.html
# analyze_html= https://docs.python.org/3.8/library/heapq.html
# analyze_html= https://docs.python.org/3.8/library/bisect.html
# analyze_html= https://docs.python.org/3.8/library/array.html
# analyze_html= https://docs.python.org/3.8/library/weakref.html
# analyze_html= https://docs.python.org/3.8/library/types.html
# analyze_html= https://docs.python.org/3.8/library/copy.html
# analyze_html= https://docs.python.org/3.8/library/pprint.html
# analyze_html= https://docs.python.org/3.8/library/reprlib.html
# analyze_html= https://docs.python.org/3.8/library/enum.html
# analyze_html= https://docs.python.org/3.8/library/numeric.html
# analyze_html= https://docs.python.org/3.8/library/numbers.html
# analyze_html= https://docs.python.org/3.8/library/math.html
# analyze_html= https://docs.python.org/3.8/library/cmath.html
# analyze_html= https://docs.python.org/3.8/library/decimal.html
# analyze_html= https://docs.python.org/3.8/library/fractions.html
# analyze_html= https://docs.python.org/3.8/library/random.html
# analyze_html= https://docs.python.org/3.8/library/statistics.html
# analyze_html= https://docs.python.org/3.8/library/functional.html
# analyze_html= https://docs.python.org/3.8/library/itertools.html
# analyze_html= https://docs.python.org/3.8/library/functools.html
# analyze_html= https://docs.python.org/3.8/library/operator.html
# analyze_html= https://docs.python.org/3.8/library/filesys.html
# analyze_html= https://docs.python.org/3.8/library/pathlib.html
# analyze_html= https://docs.python.org/3.8/library/os.path.html
# analyze_html= https://docs.python.org/3.8/library/fileinput.html
# analyze_html= https://docs.python.org/3.8/library/stat.html
# analyze_html= https://docs.python.org/3.8/library/filecmp.html
# analyze_html= https://docs.python.org/3.8/library/tempfile.html
# analyze_html= https://docs.python.org/3.8/library/glob.html
# analyze_html= https://docs.python.org/3.8/library/fnmatch.html
# analyze_html= https://docs.python.org/3.8/library/linecache.html
# analyze_html= https://docs.python.org/3.8/library/shutil.html
# download= https://docs.python.org/3.8/library/persistence.html
# analyze_html= https://docs.python.org/3.8/library/persistence.html
# download= https://docs.python.org/3.8/library/pickle.html
# analyze_html= https://docs.python.org/3.8/library/pickle.html
# download= https://docs.python.org/3.8/library/copyreg.html
# analyze_html= https://docs.python.org/3.8/library/copyreg.html
# download= https://docs.python.org/3.8/library/shelve.html
# analyze_html= https://docs.python.org/3.8/library/shelve.html
# download= https://docs.python.org/3.8/library/marshal.html
# analyze_html= https://docs.python.org/3.8/library/marshal.html
# download= https://docs.python.org/3.8/library/dbm.html
# analyze_html= https://docs.python.org/3.8/library/dbm.html
# download= https://docs.python.org/3.8/library/sqlite3.html
# analyze_html= https://docs.python.org/3.8/library/sqlite3.html
# download= https://docs.python.org/3.8/library/archiving.html
# analyze_html= https://docs.python.org/3.8/library/archiving.html
# download= https://docs.python.org/3.8/library/zlib.html
# analyze_html= https://docs.python.org/3.8/library/zlib.html
# download= https://docs.python.org/3.8/library/gzip.html
# analyze_html= https://docs.python.org/3.8/library/gzip.html
# download= https://docs.python.org/3.8/library/bz2.html
# analyze_html= https://docs.python.org/3.8/library/bz2.html
# download= https://docs.python.org/3.8/library/lzma.html
# analyze_html= https://docs.python.org/3.8/library/lzma.html
# download= https://docs.python.org/3.8/library/zipfile.html
# analyze_html= https://docs.python.org/3.8/library/zipfile.html
# download= https://docs.python.org/3.8/library/tarfile.html
# analyze_html= https://docs.python.org/3.8/library/tarfile.html
# download= https://docs.python.org/3.8/library/fileformats.html
# analyze_html= https://docs.python.org/3.8/library/fileformats.html
# download= https://docs.python.org/3.8/library/csv.html
# analyze_html= https://docs.python.org/3.8/library/csv.html
# download= https://docs.python.org/3.8/library/configparser.html
# analyze_html= https://docs.python.org/3.8/library/configparser.html
# download= https://docs.python.org/3.8/library/netrc.html
# analyze_html= https://docs.python.org/3.8/library/netrc.html
# download= https://docs.python.org/3.8/library/xdrlib.html
# analyze_html= https://docs.python.org/3.8/library/xdrlib.html
# download= https://docs.python.org/3.8/library/plistlib.html
# analyze_html= https://docs.python.org/3.8/library/plistlib.html
# download= https://docs.python.org/3.8/library/crypto.html
# analyze_html= https://docs.python.org/3.8/library/crypto.html
# download= https://docs.python.org/3.8/library/hashlib.html
# analyze_html= https://docs.python.org/3.8/library/hashlib.html
# download= https://docs.python.org/3.8/library/hmac.html
# analyze_html= https://docs.python.org/3.8/library/hmac.html
# download= https://docs.python.org/3.8/library/secrets.html
# analyze_html= https://docs.python.org/3.8/library/secrets.html
# download= https://docs.python.org/3.8/library/allos.html
# analyze_html= https://docs.python.org/3.8/library/allos.html
# download= https://docs.python.org/3.8/library/os.html
# analyze_html= https://docs.python.org/3.8/library/os.html
# download= https://docs.python.org/3.8/library/io.html
# analyze_html= https://docs.python.org/3.8/library/io.html
# download= https://docs.python.org/3.8/library/time.html
# analyze_html= https://docs.python.org/3.8/library/time.html
# download= https://docs.python.org/3.8/library/argparse.html
# analyze_html= https://docs.python.org/3.8/library/argparse.html
# download= https://docs.python.org/3.8/library/getopt.html
# analyze_html= https://docs.python.org/3.8/library/getopt.html
# download= https://docs.python.org/3.8/library/logging.html
# analyze_html= https://docs.python.org/3.8/library/logging.html
# download= https://docs.python.org/3.8/library/logging.config.html
# analyze_html= https://docs.python.org/3.8/library/logging.config.html
# download= https://docs.python.org/3.8/library/logging.handlers.html
# analyze_html= https://docs.python.org/3.8/library/logging.handlers.html
# download= https://docs.python.org/3.8/library/getpass.html
# analyze_html= https://docs.python.org/3.8/library/getpass.html
# download= https://docs.python.org/3.8/library/curses.html
# analyze_html= https://docs.python.org/3.8/library/curses.html
# download= https://docs.python.org/3.8/library/curses.ascii.html
# analyze_html= https://docs.python.org/3.8/library/curses.ascii.html
# download= https://docs.python.org/3.8/library/curses.panel.html
# analyze_html= https://docs.python.org/3.8/library/curses.panel.html
# download= https://docs.python.org/3.8/library/platform.html
# analyze_html= https://docs.python.org/3.8/library/platform.html
# download= https://docs.python.org/3.8/library/errno.html
# analyze_html= https://docs.python.org/3.8/library/errno.html
# download= https://docs.python.org/3.8/library/ctypes.html
# analyze_html= https://docs.python.org/3.8/library/ctypes.html
# download= https://docs.python.org/3.8/library/concurrency.html
# analyze_html= https://docs.python.org/3.8/library/concurrency.html
# download= https://docs.python.org/3.8/library/threading.html
# analyze_html= https://docs.python.org/3.8/library/threading.html
# download= https://docs.python.org/3.8/library/multiprocessing.html
# analyze_html= https://docs.python.org/3.8/library/multiprocessing.html
# download= https://docs.python.org/3.8/library/multiprocessing.shared_memory.html
# analyze_html= https://docs.python.org/3.8/library/multiprocessing.shared_memory.html
# download= https://docs.python.org/3.8/library/concurrent.html
# analyze_html= https://docs.python.org/3.8/library/concurrent.html
# download= https://docs.python.org/3.8/library/concurrent.futures.html
# analyze_html= https://docs.python.org/3.8/library/concurrent.futures.html
# download= https://docs.python.org/3.8/library/subprocess.html
# analyze_html= https://docs.python.org/3.8/library/subprocess.html
# download= https://docs.python.org/3.8/library/sched.html
# analyze_html= https://docs.python.org/3.8/library/sched.html
# download= https://docs.python.org/3.8/library/queue.html
# analyze_html= https://docs.python.org/3.8/library/queue.html
# download= https://docs.python.org/3.8/library/_thread.html
# analyze_html= https://docs.python.org/3.8/library/_thread.html
# download= https://docs.python.org/3.8/library/_dummy_thread.html
# analyze_html= https://docs.python.org/3.8/library/_dummy_thread.html
# download= https://docs.python.org/3.8/library/dummy_threading.html
# analyze_html= https://docs.python.org/3.8/library/dummy_threading.html
# download= https://docs.python.org/3.8/library/contextvars.html
# analyze_html= https://docs.python.org/3.8/library/contextvars.html
# download= https://docs.python.org/3.8/library/ipc.html
# analyze_html= https://docs.python.org/3.8/library/ipc.html
# download= https://docs.python.org/3.8/library/asyncio.html
# analyze_html= https://docs.python.org/3.8/library/asyncio.html
# download= https://docs.python.org/3.8/library/asyncio-task.html
# analyze_html= https://docs.python.org/3.8/library/asyncio-task.html
# download= https://docs.python.org/3.8/library/asyncio-stream.html
# analyze_html= https://docs.python.org/3.8/library/asyncio-stream.html
# download= https://docs.python.org/3.8/library/asyncio-sync.html
# analyze_html= https://docs.python.org/3.8/library/asyncio-sync.html
# download= https://docs.python.org/3.8/library/asyncio-subprocess.html
# analyze_html= https://docs.python.org/3.8/library/asyncio-subprocess.html
# download= https://docs.python.org/3.8/library/asyncio-queue.html
# analyze_html= https://docs.python.org/3.8/library/asyncio-queue.html
# download= https://docs.python.org/3.8/library/asyncio-exceptions.html
# analyze_html= https://docs.python.org/3.8/library/asyncio-exceptions.html
# download= https://docs.python.org/3.8/library/asyncio-eventloop.html
# analyze_html= https://docs.python.org/3.8/library/asyncio-eventloop.html
# download= https://docs.python.org/3.8/library/asyncio-future.html
# analyze_html= https://docs.python.org/3.8/library/asyncio-future.html
# download= https://docs.python.org/3.8/library/asyncio-protocol.html
# analyze_html= https://docs.python.org/3.8/library/asyncio-protocol.html
# download= https://docs.python.org/3.8/library/asyncio-policy.html
# analyze_html= https://docs.python.org/3.8/library/asyncio-policy.html
# download= https://docs.python.org/3.8/library/asyncio-platforms.html
# analyze_html= https://docs.python.org/3.8/library/asyncio-platforms.html
# download= https://docs.python.org/3.8/library/asyncio-api-index.html
# analyze_html= https://docs.python.org/3.8/library/asyncio-api-index.html
# download= https://docs.python.org/3.8/library/asyncio-llapi-index.html
# analyze_html= https://docs.python.org/3.8/library/asyncio-llapi-index.html
# download= https://docs.python.org/3.8/library/asyncio-dev.html
# analyze_html= https://docs.python.org/3.8/library/asyncio-dev.html
# download= https://docs.python.org/3.8/library/socket.html
# analyze_html= https://docs.python.org/3.8/library/socket.html
# download= https://docs.python.org/3.8/library/ssl.html
# analyze_html= https://docs.python.org/3.8/library/ssl.html
# download= https://docs.python.org/3.8/library/select.html
# analyze_html= https://docs.python.org/3.8/library/select.html
# download= https://docs.python.org/3.8/library/selectors.html
# analyze_html= https://docs.python.org/3.8/library/selectors.html
# download= https://docs.python.org/3.8/library/asyncore.html
# analyze_html= https://docs.python.org/3.8/library/asyncore.html
# download= https://docs.python.org/3.8/library/asynchat.html
# analyze_html= https://docs.python.org/3.8/library/asynchat.html
# download= https://docs.python.org/3.8/library/signal.html
# analyze_html= https://docs.python.org/3.8/library/signal.html
# download= https://docs.python.org/3.8/library/mmap.html
# analyze_html= https://docs.python.org/3.8/library/mmap.html
# download= https://docs.python.org/3.8/library/netdata.html
# analyze_html= https://docs.python.org/3.8/library/netdata.html
# download= https://docs.python.org/3.8/library/email.html
# analyze_html= https://docs.python.org/3.8/library/email.html
# download= https://docs.python.org/3.8/library/email.message.html
# analyze_html= https://docs.python.org/3.8/library/email.message.html
# download= https://docs.python.org/3.8/library/email.parser.html
# analyze_html= https://docs.python.org/3.8/library/email.parser.html
# download= https://docs.python.org/3.8/library/email.generator.html
# analyze_html= https://docs.python.org/3.8/library/email.generator.html
# download= https://docs.python.org/3.8/library/email.policy.html
# analyze_html= https://docs.python.org/3.8/library/email.policy.html
# download= https://docs.python.org/3.8/library/email.errors.html
# analyze_html= https://docs.python.org/3.8/library/email.errors.html
# download= https://docs.python.org/3.8/library/email.headerregistry.html
# analyze_html= https://docs.python.org/3.8/library/email.headerregistry.html
# download= https://docs.python.org/3.8/library/email.contentmanager.html
# analyze_html= https://docs.python.org/3.8/library/email.contentmanager.html
# download= https://docs.python.org/3.8/library/email.examples.html
# analyze_html= https://docs.python.org/3.8/library/email.examples.html
# download= https://docs.python.org/3.8/library/email.compat32-message.html
# analyze_html= https://docs.python.org/3.8/library/email.compat32-message.html
# download= https://docs.python.org/3.8/library/email.mime.html
# analyze_html= https://docs.python.org/3.8/library/email.mime.html
# download= https://docs.python.org/3.8/library/email.header.html
# analyze_html= https://docs.python.org/3.8/library/email.header.html
# download= https://docs.python.org/3.8/library/email.charset.html
# analyze_html= https://docs.python.org/3.8/library/email.charset.html
# download= https://docs.python.org/3.8/library/email.encoders.html
# analyze_html= https://docs.python.org/3.8/library/email.encoders.html
# download= https://docs.python.org/3.8/library/email.utils.html
# analyze_html= https://docs.python.org/3.8/library/email.utils.html
# download= https://docs.python.org/3.8/library/email.iterators.html
# analyze_html= https://docs.python.org/3.8/library/email.iterators.html
# download= https://docs.python.org/3.8/library/json.html
# analyze_html= https://docs.python.org/3.8/library/json.html
# download= https://docs.python.org/3.8/library/mailcap.html
# analyze_html= https://docs.python.org/3.8/library/mailcap.html
# download= https://docs.python.org/3.8/library/mailbox.html
# analyze_html= https://docs.python.org/3.8/library/mailbox.html
# download= https://docs.python.org/3.8/library/mimetypes.html
# analyze_html= https://docs.python.org/3.8/library/mimetypes.html
# download= https://docs.python.org/3.8/library/base64.html
# analyze_html= https://docs.python.org/3.8/library/base64.html
# download= https://docs.python.org/3.8/library/binhex.html
# analyze_html= https://docs.python.org/3.8/library/binhex.html
# download= https://docs.python.org/3.8/library/binascii.html
# analyze_html= https://docs.python.org/3.8/library/binascii.html
# download= https://docs.python.org/3.8/library/quopri.html
# analyze_html= https://docs.python.org/3.8/library/quopri.html
# download= https://docs.python.org/3.8/library/uu.html
# analyze_html= https://docs.python.org/3.8/library/uu.html
# download= https://docs.python.org/3.8/library/markup.html
# analyze_html= https://docs.python.org/3.8/library/markup.html
# download= https://docs.python.org/3.8/library/html.html
# analyze_html= https://docs.python.org/3.8/library/html.html
# download= https://docs.python.org/3.8/library/html.parser.html
# analyze_html= https://docs.python.org/3.8/library/html.parser.html
# download= https://docs.python.org/3.8/library/html.entities.html
# analyze_html= https://docs.python.org/3.8/library/html.entities.html
# download= https://docs.python.org/3.8/library/xml.html
# analyze_html= https://docs.python.org/3.8/library/xml.html
# download= https://docs.python.org/3.8/library/xml.etree.elementtree.html
# analyze_html= https://docs.python.org/3.8/library/xml.etree.elementtree.html
# download= https://docs.python.org/3.8/library/xml.dom.html
# analyze_html= https://docs.python.org/3.8/library/xml.dom.html
# download= https://docs.python.org/3.8/library/xml.dom.minidom.html
# analyze_html= https://docs.python.org/3.8/library/xml.dom.minidom.html
# download= https://docs.python.org/3.8/library/xml.dom.pulldom.html
# analyze_html= https://docs.python.org/3.8/library/xml.dom.pulldom.html
# download= https://docs.python.org/3.8/library/xml.sax.html
# analyze_html= https://docs.python.org/3.8/library/xml.sax.html
# download= https://docs.python.org/3.8/library/xml.sax.handler.html
# analyze_html= https://docs.python.org/3.8/library/xml.sax.handler.html
# download= https://docs.python.org/3.8/library/xml.sax.utils.html
# analyze_html= https://docs.python.org/3.8/library/xml.sax.utils.html
# download= https://docs.python.org/3.8/library/xml.sax.reader.html
# analyze_html= https://docs.python.org/3.8/library/xml.sax.reader.html
# download= https://docs.python.org/3.8/library/pyexpat.html
# analyze_html= https://docs.python.org/3.8/library/pyexpat.html
# download= https://docs.python.org/3.8/library/internet.html
# analyze_html= https://docs.python.org/3.8/library/internet.html
# download= https://docs.python.org/3.8/library/webbrowser.html
# analyze_html= https://docs.python.org/3.8/library/webbrowser.html
# download= https://docs.python.org/3.8/library/cgi.html
# analyze_html= https://docs.python.org/3.8/library/cgi.html
# download= https://docs.python.org/3.8/library/cgitb.html
# analyze_html= https://docs.python.org/3.8/library/cgitb.html
# download= https://docs.python.org/3.8/library/wsgiref.html
# analyze_html= https://docs.python.org/3.8/library/wsgiref.html
# download= https://docs.python.org/3.8/library/urllib.html
# analyze_html= https://docs.python.org/3.8/library/urllib.html
# download= https://docs.python.org/3.8/library/urllib.request.html
# analyze_html= https://docs.python.org/3.8/library/urllib.request.html
# download= https://docs.python.org/3.8/library/urllib.parse.html
# analyze_html= https://docs.python.org/3.8/library/urllib.parse.html
# download= https://docs.python.org/3.8/library/urllib.error.html
# analyze_html= https://docs.python.org/3.8/library/urllib.error.html
# download= https://docs.python.org/3.8/library/urllib.robotparser.html
# analyze_html= https://docs.python.org/3.8/library/urllib.robotparser.html
# download= https://docs.python.org/3.8/library/http.html
# analyze_html= https://docs.python.org/3.8/library/http.html
# download= https://docs.python.org/3.8/library/http.client.html
# analyze_html= https://docs.python.org/3.8/library/http.client.html
# download= https://docs.python.org/3.8/library/ftplib.html
# analyze_html= https://docs.python.org/3.8/library/ftplib.html
# download= https://docs.python.org/3.8/library/poplib.html
# analyze_html= https://docs.python.org/3.8/library/poplib.html
# download= https://docs.python.org/3.8/library/imaplib.html
# analyze_html= https://docs.python.org/3.8/library/imaplib.html
# download= https://docs.python.org/3.8/library/nntplib.html
# analyze_html= https://docs.python.org/3.8/library/nntplib.html
# download= https://docs.python.org/3.8/library/smtplib.html
# analyze_html= https://docs.python.org/3.8/library/smtplib.html
# download= https://docs.python.org/3.8/library/smtpd.html
# analyze_html= https://docs.python.org/3.8/library/smtpd.html
# download= https://docs.python.org/3.8/library/telnetlib.html
# analyze_html= https://docs.python.org/3.8/library/telnetlib.html
# download= https://docs.python.org/3.8/library/uuid.html
# analyze_html= https://docs.python.org/3.8/library/uuid.html
# download= https://docs.python.org/3.8/library/socketserver.html
# analyze_html= https://docs.python.org/3.8/library/socketserver.html
# download= https://docs.python.org/3.8/library/http.server.html
# analyze_html= https://docs.python.org/3.8/library/http.server.html
# download= https://docs.python.org/3.8/library/http.cookies.html
# analyze_html= https://docs.python.org/3.8/library/http.cookies.html
# download= https://docs.python.org/3.8/library/http.cookiejar.html
# analyze_html= https://docs.python.org/3.8/library/http.cookiejar.html
# download= https://docs.python.org/3.8/library/xmlrpc.html
# analyze_html= https://docs.python.org/3.8/library/xmlrpc.html
# download= https://docs.python.org/3.8/library/xmlrpc.client.html
# analyze_html= https://docs.python.org/3.8/library/xmlrpc.client.html
# download= https://docs.python.org/3.8/library/xmlrpc.server.html
# analyze_html= https://docs.python.org/3.8/library/xmlrpc.server.html
# download= https://docs.python.org/3.8/library/ipaddress.html
# analyze_html= https://docs.python.org/3.8/library/ipaddress.html
# download= https://docs.python.org/3.8/library/mm.html
# analyze_html= https://docs.python.org/3.8/library/mm.html
# download= https://docs.python.org/3.8/library/audioop.html
# analyze_html= https://docs.python.org/3.8/library/audioop.html
# download= https://docs.python.org/3.8/library/aifc.html
# analyze_html= https://docs.python.org/3.8/library/aifc.html
# download= https://docs.python.org/3.8/library/sunau.html
# analyze_html= https://docs.python.org/3.8/library/sunau.html
# download= https://docs.python.org/3.8/library/wave.html
# analyze_html= https://docs.python.org/3.8/library/wave.html
# download= https://docs.python.org/3.8/library/chunk.html
# analyze_html= https://docs.python.org/3.8/library/chunk.html
# download= https://docs.python.org/3.8/library/colorsys.html
# analyze_html= https://docs.python.org/3.8/library/colorsys.html
# download= https://docs.python.org/3.8/library/imghdr.html
# analyze_html= https://docs.python.org/3.8/library/imghdr.html
# download= https://docs.python.org/3.8/library/sndhdr.html
# analyze_html= https://docs.python.org/3.8/library/sndhdr.html
# download= https://docs.python.org/3.8/library/ossaudiodev.html
# analyze_html= https://docs.python.org/3.8/library/ossaudiodev.html
# download= https://docs.python.org/3.8/library/i18n.html
# analyze_html= https://docs.python.org/3.8/library/i18n.html
# download= https://docs.python.org/3.8/library/gettext.html
# analyze_html= https://docs.python.org/3.8/library/gettext.html
# download= https://docs.python.org/3.8/library/locale.html
# analyze_html= https://docs.python.org/3.8/library/locale.html
# download= https://docs.python.org/3.8/library/frameworks.html
# analyze_html= https://docs.python.org/3.8/library/frameworks.html
# download= https://docs.python.org/3.8/library/turtle.html
# analyze_html= https://docs.python.org/3.8/library/turtle.html
# download= https://docs.python.org/3.8/library/cmd.html
# analyze_html= https://docs.python.org/3.8/library/cmd.html
# download= https://docs.python.org/3.8/library/shlex.html
# analyze_html= https://docs.python.org/3.8/library/shlex.html
# download= https://docs.python.org/3.8/library/tk.html
# analyze_html= https://docs.python.org/3.8/library/tk.html
# download= https://docs.python.org/3.8/library/tkinter.html
# analyze_html= https://docs.python.org/3.8/library/tkinter.html
# download= https://docs.python.org/3.8/library/tkinter.ttk.html
# analyze_html= https://docs.python.org/3.8/library/tkinter.ttk.html
# download= https://docs.python.org/3.8/library/tkinter.tix.html
# analyze_html= https://docs.python.org/3.8/library/tkinter.tix.html
# download= https://docs.python.org/3.8/library/tkinter.scrolledtext.html
# analyze_html= https://docs.python.org/3.8/library/tkinter.scrolledtext.html
# download= https://docs.python.org/3.8/library/idle.html
# analyze_html= https://docs.python.org/3.8/library/idle.html
# download= https://docs.python.org/3.8/library/othergui.html
# analyze_html= https://docs.python.org/3.8/library/othergui.html
# download= https://docs.python.org/3.8/library/development.html
# analyze_html= https://docs.python.org/3.8/library/development.html
# download= https://docs.python.org/3.8/library/typing.html
# analyze_html= https://docs.python.org/3.8/library/typing.html
# download= https://docs.python.org/3.8/library/pydoc.html
# analyze_html= https://docs.python.org/3.8/library/pydoc.html
# download= https://docs.python.org/3.8/library/doctest.html
# analyze_html= https://docs.python.org/3.8/library/doctest.html
# download= https://docs.python.org/3.8/library/unittest.html
# analyze_html= https://docs.python.org/3.8/library/unittest.html
# download= https://docs.python.org/3.8/library/unittest.mock.html
# analyze_html= https://docs.python.org/3.8/library/unittest.mock.html
# download= https://docs.python.org/3.8/library/unittest.mock-examples.html
# analyze_html= https://docs.python.org/3.8/library/unittest.mock-examples.html
# download= https://docs.python.org/3.8/library/2to3.html
# analyze_html= https://docs.python.org/3.8/library/2to3.html
# download= https://docs.python.org/3.8/library/test.html
# analyze_html= https://docs.python.org/3.8/library/test.html
# download= https://docs.python.org/3.8/library/debug.html
# analyze_html= https://docs.python.org/3.8/library/debug.html
# download= https://docs.python.org/3.8/library/audit_events.html
# analyze_html= https://docs.python.org/3.8/library/audit_events.html
# download= https://docs.python.org/3.8/library/bdb.html
# analyze_html= https://docs.python.org/3.8/library/bdb.html
# download= https://docs.python.org/3.8/library/faulthandler.html
# analyze_html= https://docs.python.org/3.8/library/faulthandler.html
# download= https://docs.python.org/3.8/library/pdb.html
# analyze_html= https://docs.python.org/3.8/library/pdb.html
# download= https://docs.python.org/3.8/library/profile.html
# analyze_html= https://docs.python.org/3.8/library/profile.html
# download= https://docs.python.org/3.8/library/timeit.html
# analyze_html= https://docs.python.org/3.8/library/timeit.html
# download= https://docs.python.org/3.8/library/trace.html
# analyze_html= https://docs.python.org/3.8/library/trace.html
# download= https://docs.python.org/3.8/library/tracemalloc.html
# analyze_html= https://docs.python.org/3.8/library/tracemalloc.html
# download= https://docs.python.org/3.8/library/distribution.html
# analyze_html= https://docs.python.org/3.8/library/distribution.html
# download= https://docs.python.org/3.8/library/distutils.html
# analyze_html= https://docs.python.org/3.8/library/distutils.html
# download= https://docs.python.org/3.8/library/ensurepip.html
# analyze_html= https://docs.python.org/3.8/library/ensurepip.html
# download= https://docs.python.org/3.8/library/venv.html
# analyze_html= https://docs.python.org/3.8/library/venv.html
# download= https://docs.python.org/3.8/library/zipapp.html
# analyze_html= https://docs.python.org/3.8/library/zipapp.html
# download= https://docs.python.org/3.8/library/python.html
# analyze_html= https://docs.python.org/3.8/library/python.html
# download= https://docs.python.org/3.8/library/sys.html
# analyze_html= https://docs.python.org/3.8/library/sys.html
# download= https://docs.python.org/3.8/library/sysconfig.html
# analyze_html= https://docs.python.org/3.8/library/sysconfig.html
# download= https://docs.python.org/3.8/library/builtins.html
# analyze_html= https://docs.python.org/3.8/library/builtins.html
# download= https://docs.python.org/3.8/library/__main__.html
# analyze_html= https://docs.python.org/3.8/library/__main__.html
# download= https://docs.python.org/3.8/library/warnings.html
# analyze_html= https://docs.python.org/3.8/library/warnings.html
# download= https://docs.python.org/3.8/library/dataclasses.html
# analyze_html= https://docs.python.org/3.8/library/dataclasses.html
# download= https://docs.python.org/3.8/library/contextlib.html
# analyze_html= https://docs.python.org/3.8/library/contextlib.html
# download= https://docs.python.org/3.8/library/abc.html
# analyze_html= https://docs.python.org/3.8/library/abc.html
# download= https://docs.python.org/3.8/library/atexit.html
# analyze_html= https://docs.python.org/3.8/library/atexit.html
# download= https://docs.python.org/3.8/library/traceback.html
# analyze_html= https://docs.python.org/3.8/library/traceback.html
# download= https://docs.python.org/3.8/library/__future__.html
# analyze_html= https://docs.python.org/3.8/library/__future__.html
# download= https://docs.python.org/3.8/library/gc.html
# analyze_html= https://docs.python.org/3.8/library/gc.html
# download= https://docs.python.org/3.8/library/inspect.html
# analyze_html= https://docs.python.org/3.8/library/inspect.html
# download= https://docs.python.org/3.8/library/site.html
# analyze_html= https://docs.python.org/3.8/library/site.html
# download= https://docs.python.org/3.8/library/custominterp.html
# analyze_html= https://docs.python.org/3.8/library/custominterp.html
# download= https://docs.python.org/3.8/library/code.html
# analyze_html= https://docs.python.org/3.8/library/code.html
# download= https://docs.python.org/3.8/library/codeop.html
# analyze_html= https://docs.python.org/3.8/library/codeop.html
# download= https://docs.python.org/3.8/library/modules.html
# analyze_html= https://docs.python.org/3.8/library/modules.html
# download= https://docs.python.org/3.8/library/zipimport.html
# analyze_html= https://docs.python.org/3.8/library/zipimport.html
# download= https://docs.python.org/3.8/library/pkgutil.html
# analyze_html= https://docs.python.org/3.8/library/pkgutil.html
# download= https://docs.python.org/3.8/library/modulefinder.html
# analyze_html= https://docs.python.org/3.8/library/modulefinder.html
# download= https://docs.python.org/3.8/library/runpy.html
# analyze_html= https://docs.python.org/3.8/library/runpy.html
# download= https://docs.python.org/3.8/library/importlib.html
# analyze_html= https://docs.python.org/3.8/library/importlib.html
# download= https://docs.python.org/3.8/library/importlib.metadata.html
# analyze_html= https://docs.python.org/3.8/library/importlib.metadata.html
# download= https://docs.python.org/3.8/library/language.html
# analyze_html= https://docs.python.org/3.8/library/language.html
# download= https://docs.python.org/3.8/library/parser.html
# analyze_html= https://docs.python.org/3.8/library/parser.html
# download= https://docs.python.org/3.8/library/ast.html
# analyze_html= https://docs.python.org/3.8/library/ast.html
# download= https://docs.python.org/3.8/library/symtable.html
# analyze_html= https://docs.python.org/3.8/library/symtable.html
# download= https://docs.python.org/3.8/library/symbol.html
# analyze_html= https://docs.python.org/3.8/library/symbol.html
# download= https://docs.python.org/3.8/library/token.html
# analyze_html= https://docs.python.org/3.8/library/token.html
# download= https://docs.python.org/3.8/library/keyword.html
# analyze_html= https://docs.python.org/3.8/library/keyword.html
# download= https://docs.python.org/3.8/library/tokenize.html
# analyze_html= https://docs.python.org/3.8/library/tokenize.html
# download= https://docs.python.org/3.8/library/tabnanny.html
# analyze_html= https://docs.python.org/3.8/library/tabnanny.html
# download= https://docs.python.org/3.8/library/pyclbr.html
# analyze_html= https://docs.python.org/3.8/library/pyclbr.html
# download= https://docs.python.org/3.8/library/py_compile.html
# analyze_html= https://docs.python.org/3.8/library/py_compile.html
# download= https://docs.python.org/3.8/library/compileall.html
# analyze_html= https://docs.python.org/3.8/library/compileall.html
# download= https://docs.python.org/3.8/library/dis.html
# analyze_html= https://docs.python.org/3.8/library/dis.html
# download= https://docs.python.org/3.8/library/pickletools.html
# analyze_html= https://docs.python.org/3.8/library/pickletools.html
# download= https://docs.python.org/3.8/library/misc.html
# analyze_html= https://docs.python.org/3.8/library/misc.html
# download= https://docs.python.org/3.8/library/formatter.html
# analyze_html= https://docs.python.org/3.8/library/formatter.html
# download= https://docs.python.org/3.8/library/windows.html
# analyze_html= https://docs.python.org/3.8/library/windows.html
# download= https://docs.python.org/3.8/library/msilib.html
# analyze_html= https://docs.python.org/3.8/library/msilib.html
# download= https://docs.python.org/3.8/library/msvcrt.html
# analyze_html= https://docs.python.org/3.8/library/msvcrt.html
# download= https://docs.python.org/3.8/library/winreg.html
# analyze_html= https://docs.python.org/3.8/library/winreg.html
# download= https://docs.python.org/3.8/library/winsound.html
# analyze_html= https://docs.python.org/3.8/library/winsound.html
# download= https://docs.python.org/3.8/library/unix.html
# analyze_html= https://docs.python.org/3.8/library/unix.html
# download= https://docs.python.org/3.8/library/posix.html
# analyze_html= https://docs.python.org/3.8/library/posix.html
# download= https://docs.python.org/3.8/library/pwd.html
# analyze_html= https://docs.python.org/3.8/library/pwd.html
# download= https://docs.python.org/3.8/library/spwd.html
# analyze_html= https://docs.python.org/3.8/library/spwd.html
# download= https://docs.python.org/3.8/library/grp.html
# analyze_html= https://docs.python.org/3.8/library/grp.html
# download= https://docs.python.org/3.8/library/crypt.html
# analyze_html= https://docs.python.org/3.8/library/crypt.html
# download= https://docs.python.org/3.8/library/termios.html
# analyze_html= https://docs.python.org/3.8/library/termios.html
# download= https://docs.python.org/3.8/library/tty.html
# analyze_html= https://docs.python.org/3.8/library/tty.html
# download= https://docs.python.org/3.8/library/pty.html
# analyze_html= https://docs.python.org/3.8/library/pty.html
# download= https://docs.python.org/3.8/library/fcntl.html
# analyze_html= https://docs.python.org/3.8/library/fcntl.html
# download= https://docs.python.org/3.8/library/pipes.html
# analyze_html= https://docs.python.org/3.8/library/pipes.html
# download= https://docs.python.org/3.8/library/resource.html
# analyze_html= https://docs.python.org/3.8/library/resource.html
# download= https://docs.python.org/3.8/library/nis.html
# analyze_html= https://docs.python.org/3.8/library/nis.html
# download= https://docs.python.org/3.8/library/syslog.html
# analyze_html= https://docs.python.org/3.8/library/syslog.html
# download= https://docs.python.org/3.8/library/superseded.html
# analyze_html= https://docs.python.org/3.8/library/superseded.html
# download= https://docs.python.org/3.8/library/optparse.html
# analyze_html= https://docs.python.org/3.8/library/optparse.html
# download= https://docs.python.org/3.8/library/imp.html
# analyze_html= https://docs.python.org/3.8/library/imp.html
# download= https://docs.python.org/3.8/library/undoc.html
# analyze_html= https://docs.python.org/3.8/library/undoc.html
